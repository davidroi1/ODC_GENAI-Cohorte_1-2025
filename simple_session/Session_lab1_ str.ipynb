# %% [markdown]
# ## Création, Indiçage, extraction, longueur

# %% [markdown]
# * Créer la variable \<chaine1\> contenant la chaine de caractère \<Cours de Python\>

# %%
# code ici
chaine1 = "Cours de Python"

# %% [markdown]
# * Afficher la chaine

# %%
# code ici
print(chaine1)
# Out:
# Cours de Python

# %% [markdown]
# * Quelle est la longeur de la chaine

# %%
# code ici
len(chaine1)
# Out:
# 15

# %% [markdown]
# * Extraire le premier caractère de la chaine (2 méthodes)

# %%
# code ici
strFirst = chaine1[0]

# %%
# code ici
print(strFirst)
# Out:
# C

# %% [markdown]
# * Extraire le dernier  caractère de la chaine (2 méthodes)

# %%
# code ici
strLast = chaine1[-1]

# %%
# code ici
print(strLast)
# Out:
# n

# %% [markdown]
# * Extraire le 7 ième caractère de la chaine (2 méthodes)

# %%
# code ici
str7 = chaine1[6]

# %%
# code ici
print(str7)
# Out:
# d

# %% [markdown]
# * Extraire le caractère \<P\> de la chaine (2 méthodes)

# %%
# code ici
strP = chaine1[5]

# %%
# code ici
print(strP)

# %% [markdown]
# ## Slicing

# %% [markdown]
# * Extraire les 3 premiers caractères de la chaine (3 méthodes)

# %%
# code ici
strFill3 = chaine1[:3]

# %%
# code ici
print(strFill3)
# Out:
# Cou

# %%
# code ici

# %% [markdown]
# * Extraire les 2 derniers caractères de la chaine (2 méthodes)

# %%
# code ici
strLastFull2 = chaine1[-2:]

# %%
# code ici
print(strLastFull2)
# Out:
# on

# %% [markdown]
# * Extraire le mot \<in\> de la chaine (3 méthodes)

# %%
# code ici
exSubChaine = chaine1[6:8]
# Out:
# de

# %% [markdown]
# * inversé la chaine

# %%
# code ici
reversedChaine = chaine1[::-1]

# %% [markdown]
# * Extraire la sous chaine avec un saut de 2 caractères

# %%
# code ici
subChaine = chaine1[::2]
print(subChaine)
# Out:
# Cusd yhn

# %% [markdown]
# ## Concaténation, répétition

# %% [markdown]
# * créer la variable \<chaine2\> contenant la chaine de caractère \<de la formation GenAI\>

# %%
# code ici
chaine2 = "de la formation GenAI"

# %% [markdown]
# * Concaténer \<chaine1\> et \<chaine2\>

# %%
# code ici
newChaine = chaine1 + " " + chaine2

# %% [markdown]
# * créer la variable \<chaine3\> contenant la chaine de caractère \<.\>

# %%
# code ici
chaine3 = "."

# %% [markdown]
# * Concaténer \<chaine1\>, \<chaine2\> et \<chaine3\>

# %%
# code ici
newChaine = chaine1 + " " + chaine2 + chaine3

# %% [markdown]
# *  répéter 3 fois la \<chaine3\>

# %%
# code ici
chaine3 = chaine3 * 3

# %% [markdown]
# * Concaténer \<chaine1\>, \<chaine2\> et 3 fois \<chaine3\>  et affecter dans la variables \<chaine\> puis afficher

# %%
# code ici
chaine = chaine1 + " " + chaine2 + chaine3
print(chaine)
# Out:
# Cours de Python de la formation GenAI...

# %% [markdown]
# # Méthodes de chaînes de caractères

# %% [markdown]
# * find(sch) : cherche la position d’une sous-chaîne sch dans la chaîne

# %% [markdown]
# Vérifier si \<Python\> et \<Genai\> appartiennent à \<chaine\>

# %%
# code ici
verifPython = chaine.find("python")
verifGenai = chaine.find("Genai")

# %% [markdown]
# * count(sch) : compte le nombre de sous-chaînes `sch` dans la chaîne

# %% [markdown]
# Compter le nombre de \<o\> dans \<chaine\>

# %%
# code ici
countO = chaine.count("o")

# %% [markdown]
# * upper() : convertit une chaîne en majuscule

# %%
# code ici
newUpperChaine = chaine.upper()

# %% [markdown]
# * lower() : convertit une chaîne en minuscule

# %% [markdown]
# Convertir \<chaine\> en minuscule

# %%
# code ici
newLowerChaine = chaine.lower()

# %% [markdown]
# * strip() : enlève les espaces éventuels au début et à la fin de la chaîne

# %% [markdown]
# * Créer la variable \<chaine4\> contenant la chaine de caractère \< string in Python \t \>

# %%
# code ici
chaine4 = " string in Python \t "

# %% [markdown]
# * replace(c1, c2) : remplace tous les caractères c1 par des caractères c2 dans la chaîne

# %% [markdown]
# Remplacer le mot \<GenAI\> par \<IA Générative\>

# %%
# code ici
chaine.replace("GenAI", "IA Générative")
# Out:
# 'Cours de Python de la formation IA Générative...'

# %% [markdown]
# * `.index("car")` : retrouve l’index de la première occurrence du caractère `car dans la chaîne

# %% [markdown]
# Donner l'index du caractère \<P\> et du mot \<Python> de la chaine

# %%
# code ici
indexP = chaine.index("P")
indexPython = chaine.index("Python")
# Out:
# 9
# 9

# %% [markdown]
# ## Formatage des chaînes de caractères

# %%
"{} {} {}".format("zéro", "un", "deux")
# Out:
# zéro un deux
